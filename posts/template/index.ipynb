# %% [markdown]
# # Template
#
# Bhagesh H.
# 2024-01-11
#
# # 1. Title here
#
# ## 1.1 Subtitle here
#
# Content here.
#
# > Quote here.
#
# In-line `code` here.
#
# ``` bash
# echo 'code block here'
# ```
#
# > **Tip with Title here**
# >
# > Note that there are five types of callouts, including: `note`, `tip`,
# > `warning`, `caution`, and `important`.
#
# Table here:
#
# | Default | Left | Right | Center |
# |---------|:-----|------:|:------:|
# | 12      | 12   |    12 |   12   |
# | 123     | 123  |   123 |  123   |
# | 1       | 1    |     1 |   1    |
#
# Demonstration of pipe table syntax
#
# Image with caption here:
#
# ![Figure 1: image caption here](attachment:image.jpg)
#
# Cross reference tags here: [Figure 1](#fig-crossrefhere)
#
# Video embed here:
#
# <https://www.youtube.com/watch?v=4n_Ckdhirnw>
#
# Code annotation here (with hover option):
#
# ``` r
# library(tidyverse)
# library(palmerpenguins)
# penguins |>
#   mutate(
#     bill_ratio = bill_depth_mm / bill_length_mm,
#     bill_area  = bill_depth_mm * bill_length_mm
#   )
# ```
#
# Line 3
# Take `penguins`, and then,
#
# Lines 4-7
# add new columns for the bill ratio and bill area.
